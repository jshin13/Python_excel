# %%
import pandas as pd
import numpy as np

# %%
# importing excel

file_path = 'C:/Users/jongm/Downloads/transcribed_Checklist_17-N-0145.xlsx';

df = pd.read_excel(file_path, sheet_name='Sheet1'); #header=None
#print (df)
range?
df.head(100)

#df?

#pd.read_excel(file_path, sheet_name=0, header=0, names=None, index_col=None, parse_cols=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skip_footer=0, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds);
# Out:
#     Subject ID                                         Timepoints  \
# 0         P001                                          Screening
# 1         P001                                          Screening
# 2         P001                                           Baseline
# 3         P002                                          Screening
# 4         P002                                           Baseline
# 5         P003                                          Screening
# 6         P003                                           Baseline
# 7         P003                                             Week 0
# 8         P003                                             Week 3
# 9         P003                                             Week 6
# 10        P003                                            Week 12
# 11        P003                                            Week 18
# 12        P003                                            Week 24
# ...

# %%
from collections import Counter
c = Counter([0,1,3,3,3,0])
print(c)
print(c[3])

temp_A = 0

temp_A = 3 if temp_A == 0 else 2

print("\ntemp_A:", temp_A, "\n")

x = 2
y = 4

parity = "even" if x % 2 is 0 else "odd"

print(parity)

print(x is 2)

print("\nAND \n", x is 2 and y)
print(x == 3 and y == 4)
print("\nOR \n", x is 2 or y)
print(x or y)
print(x == 3 or y == 4)

print("\nlambda usage\n", (lambda x: x if x+1 is not 0 else 0)(12))
print((lambda x: x+1)(10))
print(x)
# Out:
# Counter({3: 3, 0: 2, 1: 1})
# 3
#
# temp_A: 3
#
# even
# True
#
# AND
#  4
# False
#
# OR
#  True
# 2
# True
#
# lambda usage
#  12
# 11
# 2
